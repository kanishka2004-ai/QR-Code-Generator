# %% [markdown]
# <a href="https://colab.research.google.com/github/kanishka2004-ai/QR-Code-Generator/blob/main/lost_cost__function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
y_predicted = np.array([1,1,0,0,1])
y_true = np.array([0.30,0.7,1,0,0.5])

# %%
def mae(y_predicted, y_true):
    total_error = 0
    for yp, yt in zip(y_predicted, y_true):
        total_error += abs(yp - yt)
    print("Total error is:",total_error)
    mae = total_error/len(y_predicted)
    print("Mean absolute error is:",mae)
    return mae

# %%
mae(y_predicted, y_true)
# Out:
# Total error is: 2.5
# Mean absolute error is: 0.5
# np.float64(0.5)

# %%
np.abs(y_predicted-y_true)
# Out:
# array([0.7, 0.3, 1. , 0. , 0.5])

# %%
np.mean(np.abs(y_predicted-y_true))
# Out:
# np.float64(0.5)

# %%
def mae_np(y_predicted, y_true):
    return np.mean(np.abs(y_predicted-y_true))

# %%
mae_np(y_predicted, y_true)
# Out:
# np.float64(0.5)

# %%
np.log([0])
# Out:
# <ipython-input-11-faee82fd9f21>:1: RuntimeWarning: divide by zero encountered in log
#   np.log([0])
# array([-inf])

# %%
epsilon = 1e-15

# %%
np.log([1e-15])
# Out:
# array([-34.53877639])

# %%
y_predicted
# Out:
# array([1, 1, 0, 0, 1])

# %%
y_predicted_new = [max(i,epsilon) for i in y_predicted]
y_predicted_new
# Out:
# [np.int64(1), np.int64(1), 1e-15, 1e-15, np.int64(1)]

# %%
1-epsilon
# Out:
# 0.999999999999999

# %%
y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
y_predicted_new
# Out:
# [0.999999999999999, 0.999999999999999, 1e-15, 1e-15, 0.999999999999999]

# %%
y_predicted_new = np.array(y_predicted_new)

# %%
np.log(y_predicted_new)
# Out:
# array([-9.99200722e-16, -9.99200722e-16, -3.45387764e+01, -3.45387764e+01,
#        -9.99200722e-16])

# %%
-np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))
# Out:
# np.float64(17.2696280766844)

# %%
def log_loss(y_true, y_predicted):
    y_predicted_new = [max(i,epsilon) for i in y_predicted]
    y_predicted_new = [min(i,1-epsilon) for i in y_predicted_new]
    y_predicted_new = np.array(y_predicted_new)
    return -np.mean(y_true*np.log(y_predicted_new)+(1-y_true)*np.log(1-y_predicted_new))

# %%
log_loss(y_true, y_predicted)
# Out:
# np.float64(17.2696280766844)

# %%
#Without Numpy
def mse(y_predicted, y_true):
    total_error = 0
    for yp, yt in zip(y_predicted, y_true):
        total_error += (yp - yt) ** 2
    mse_value = total_error / len(y_predicted)
    return mse_value

print(mse(y_predicted, y_true))
# Out:
# 0.366

# %%
#With Numpy
def mse_np(y_predicted, y_true):
    return np.mean((y_predicted - y_true) ** 2)

print(mse_np(y_predicted, y_true))
# Out:
# 0.366
